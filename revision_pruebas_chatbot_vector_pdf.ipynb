# %%
# Instalacion de dependencias
# !pip install -q pandas

# %%
# Importar librerías
import pandas as pd
import os

# %%
# Ruta base
ruta_base = "/content/drive/MyDrive/Proyectos/Versiones ChatBot/BERT/"

# Cargar CSV
df_100 = pd.read_csv(os.path.join(ruta_base, "resultados_pruebas.csv"))

# %%
# Agregar columna para identificar origen
df_100["origen"] = "100"

# Unir todo
df_total = pd.concat([df_100], ignore_index=True)

# Normalizar preguntas para agrupar
df_total["pregunta_norm"] = df_total["pregunta"].str.strip().str.lower()

# Agrupar por pregunta normalizada
agrupado = df_total.groupby("pregunta_norm")

# Lista para guardar resultados
filas_finales = []

# %%
# Evaluación manual
for pregunta_norm, grupo in agrupado:
    print("="*80)
    pregunta_original = grupo.iloc[0]["pregunta"]
    tipo_pregunta = grupo.iloc[0]["tipo_pregunta"]
    respuesta_esperada = grupo.iloc[0]["respuesta_esperada"]

    print(f" Pregunta: {pregunta_original}")
    print(f" Respuesta esperada: {respuesta_esperada}\n")

    for idx, fila in grupo.iterrows():
        print(f" Origen: {fila['origen']}")
        print(f"   Respuesta obtenida: {fila['respuesta_obtenida']}")
        print(f"   Precisión original: {fila['puntaje']}") # Corrected from 'precision' to 'puntaje'
        print("-" * 40)

    # Entrada manual
    nueva_precision = input(" Ingresá nueva precisión final: ").strip()
    nueva_observacion = input(" Ingresá observación final: ").strip()

    fila_resultante = {
        "tipo_pregunta": tipo_pregunta,
        "pregunta": pregunta_original,
        "respuesta_esperada": respuesta_esperada,
        "respuesta_obtenida": grupo.iloc[0]["respuesta_obtenida"],  # podrías elegir la mejor si querés
        "puntaje": nueva_precision,
        "observaciones": nueva_observacion
    }

    filas_finales.append(fila_resultante)

    print(" Respuesta guardada.\n")
# Out:
# ================================================================================
#  Pregunta: Compara el control de flujo y el control de congestión en TCP
#  Respuesta esperada: Flujo evita desbordar el receptor, congestión evita saturar la red
#
#  Origen: 100
#    Respuesta obtenida: El control de flujo de TCP es un servicio de adaptación de velocidades que ayuda a la aplicación a mantener la conectividad de la red mientras se transmite un paquete. El control de flujo es un servicio de adaptación de velocidades que ayuda a la aplicación a mantener la conectividad de la red mientras se transm.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final: No responde a la pregunta
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Compara Go-Back-N y Repetición Selectiva
#  Respuesta esperada: Go-Back-N retransmite todos los paquetes desde el perdido, RS solo los necesarios
#
#  Origen: 100
#    Respuesta obtenida: Go-Back-N es más eficaz en el control de errores en redes de transmisión de datos, pero no es tan eficaz en el control de errores en redes de transmisión de paquetes. Repetición Selectiva es más eficaz en el control de errores en redes de transmisión de paquetes, pero no es tan.
#    Precisión original: 2
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final: Respondio mal
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Compara las funciones de las capas 2 y 3 del modelo OSI
#  Respuesta esperada: Capa 2 (Enlace): direccionamiento físico, control de acceso al medio. Capa 3 (Red): enrutamiento, direccionamiento lógico
#
#  Origen: 100
#    Respuesta obtenida: Las funciones de las capas 2 y 3 del modelo OSI son similares, pero tienen diferencias importantes. Las capas 2 y 3 del modelo OSI proporcionan la infraestructura de red y la comunicación entre procesos, respectivamente. Sin embargo, las funciones de las capas 2 y 3 son diferentes. Las cap.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final: No respondio y esta incompleto
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Compara los modelos OSI y TCP/IP
#  Respuesta esperada: OSI tiene 7 capas, TCP/IP combina aplicación/presentación/sesión
#
#  Origen: 100
#    Respuesta obtenida: Los modelos OSI y TCP/IP son dos modelos de arquitectura de redes que proporcionan una arquitectura de red más completa y flexible. Ambos modelos están diseñados para proporcionar una interfaz de red simple y fácil de usar para los desarrolladores y administradores de redes. Sin embargo, hay diferencias importantes entre ellos.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final: incompleta y generica
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Compara los protocolos OSPF y RIP
#  Respuesta esperada: OSPF: estado de enlace, converge rápido, usa áreas. RIP: vector distancia, límite de 15 saltos, más simple
#
#  Origen: 100
#    Respuesta obtenida: OSPF y RIP son dos protocolos de rutas de red que se utilizan para gestionar la red de redes internas. Ambos protocolos tienen características similares, pero también tienen diferencias importantes. En este artículo, veremos las principales diferencias entre OSPF y RIP.
#
# Diferencia principal: RIP es un protocol.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final: incompleta e incorrecta en parte
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Compara TCP Reno y TCP Tahoe
#  Respuesta esperada: Tahoe vuelve a slow start tras pérdida, Reno usa fast recovery
#
#  Origen: 100
#    Respuesta obtenida: TCP Reno es una variante posterior del protocolo TCP que se desarrolló en respuesta a la congestión de la red en Internet a finales de los años 90. El algoritmo de control de congestión de TCP Reno utiliza una estrategia de "Fast Recovery" en lugar de Slow Start y Congestion Avoidance.
#    Precisión original: 3
# ----------------------------------------
#  Ingresá nueva precisión final: 3
#  Ingresá observación final: Responde parte de la pregunta, debo agrandar la cantidad de palabras para las respuestas
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Compara TCP Tahoe y TCP Reno
#  Respuesta esperada: Tahoe siempre entra en slow start ante pérdidas, Reno tiene fast recovery
#
#  Origen: 100
#    Respuesta obtenida: TCP Tahoe y TCP Reno son dos versiones del protocolo TCP que se han desarrollado para resolver problemas de congestión de red. En general, las versiones más recientes de TCP, como TCP Reno, están diseñadas para mejorar la velocidad de transmisión y la estabilidad de la red. Sin embargo, ambos protocolos tienen sus pro.
#    Precisión original: 2
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final: incompleta
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Compara TCP y UDP en cuanto a uso de recursos
#  Respuesta esperada: TCP necesita más memoria y estado, UDP es más liviano
#
#  Origen: 100
#    Respuesta obtenida: En general, UDP es más eficaz en el uso de recursos que TCP. En UDP, cada mensaje de datos se envía como un segmento de datos, mientras que en TCP, cada mensaje de datos se envía como un paquete de datos. Además, en UDP, cada mensaje de datos puede ser enviado a cualquier destino, mientras.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final: erronea e incompleta
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Compara UDP y TCP en términos de fiabilidad y control de flujo
#  Respuesta esperada: TCP es orientado a conexión y fiable con control de flujo, UDP es no orientado a conexión sin garantías
#
#  Origen: 100
#    Respuesta obtenida: UDP es un protocolo sin conexión, por lo que no hay forma de garantizar la fiabilidad de los datos que se envían. El protocolo UDP no tiene una fase de estabilización antes de la transmisión de datos. Además, UDP no tiene una fase de establecimiento de la conexión entre las entidades de la capa de trans.
#    Precisión original: 2
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe cómo actúa el receptor en Go-Back-N
#  Respuesta esperada: Solo acepta paquetes en orden, descarta el resto
#
#  Origen: 100
#    Respuesta obtenida: El receptor actúa como un receptor de transmisión de datos, que recibe los paquetes de entrada y los envía a su destino. Cuando recibe un paquete, el receptor le asigna un identificador (ID) al paquete. El ID es un número único que identifica el paquete en el receptor. El.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final: incompleta
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe cómo BGP evita bucles de enrutamiento
#  Respuesta esperada: Verifica el AS-PATH para asegurar que la ruta no pasa dos veces por el mismo AS
#
#  Origen: 100
#    Respuesta obtenida: BGP utiliza técnicas de propagación de información de enrutamiento para evitar bucles de enrutamiento. La propagación de información de enrutamiento es la manera en que los routers de BGP transmiten información sobre la disponibilidad de rutas a los otros routers de BGP. Cuando un router recibe una solicitud de enrutamiento de.
#    Precisión original: 2
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe cómo funciona el algoritmo de ventana deslizante en TCP
#  Respuesta esperada: El emisor puede enviar múltiples segmentos sin esperar ACK individuales, ajustando la ventana según ACKs recibidos
#
#  Origen: 100
#    Respuesta obtenida: El algoritmo de ventana deslizante en TCP es un mecanismo de retransmisión de datos que permite a los clientes TCP descubrir la velocidad de transmisión de la conexión TCP y así decidir si la conexión está establecida o no. Esta ventana es un deslizante que se desplaza hacia ab.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe cómo opera el algoritmo de Dijkstra
#  Respuesta esperada: Calcula las rutas más cortas usando información global de costos
#
#  Origen: 100
#    Respuesta obtenida: El algoritmo de Dijkstra es un algoritmo iterativo de enrutamiento de redes de grafos. Su objetivo es encontrar una ruta de menor coste desde un nodo de origen al destino, utilizando los nodos vecinos como puntos de referencia. Para ello, el algoritmo inicia con un nodo de.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final: respuesta vaga y generica, e incompleta
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe cómo opera el algoritmo de evitación de congestión
#  Respuesta esperada: Incrementa cwnd linealmente si no hay pérdida, lo reduce si hay pérdida
#
#  Origen: 100
#    Respuesta obtenida: El algoritmo de evitación de congestión consiste en la eliminación de nodos con altos costes de transporte. Este algoritmo funciona de la siguiente manera:
#
# 1. Crea un vector de costes de todas las rutas de coste mínimo desde el origen hasta cualquier nodo de la red.
# 2.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe cómo se realiza la demultiplexación en TCP
#  Respuesta esperada: Se usa IP origen/destino y puertos para identificar sockets únicos
#
#  Origen: 100
#    Respuesta obtenida: Se realiza mediante la división del valor de cwnd (añadiendo 3 MSS como forma de tener en cuenta los tres ACK duplicados que se han recibido) y configurando el valor de umbralAL para que sea igual a la mitad del valor que cwnd había cuando se recibieron los tres ACK duplicados. Rec.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe cómo un router fragmenta datagramas IP
#  Respuesta esperada: Divide el datagrama en fragmentos más pequeños con campos especiales de IP
#
#  Origen: 100
#    Respuesta obtenida: Un router fragmenta los datos de un datagrama IP en varias partes. El primer paso es identificar el origen del datagrama. El router lee la cabecera del datagrama y compara el número de identificación con el número de identificación del datagrama original. Si los números de identificación coinciden, el router marca el datagrama.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe el proceso de establecimiento de conexión en TCP
#  Respuesta esperada: Three-way handshake: 1. Cliente envía SYN, 2. Servidor responde SYN-ACK, 3. Cliente envía ACK
#
#  Origen: 100
#    Respuesta obtenida: En el proceso de establecimiento de conexión en TCP, dos procesos de aplicación se comunican entre sí. Estos dos procesos son el cliente y el servidor. Los dos procesos se conocen como "cliente" y "servidor". El cliente inicia una conexión TCP con el servidor. El servidor también inicia una.
#    Precisión original: 2
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe el proceso de fragmentación IP
#  Respuesta esperada: Cuando un paquete excede la MTU, se divide en fragmentos con cabeceras IP que incluyen campos de identificación, offset y bandera MF
#
#  Origen: 100
#    Respuesta obtenida: El proceso de fragmentación IP es la forma en que IP entrega los datos entre dos sistemas terminales a un servicio de entrega entre dos procesos que están ejecutándose en los sistemas terminales. Los datos se fragmentan en varios segmentos, cada uno de los cuales se envía a un socket de destino diferente. El protocolo de segment.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe el proceso DHCP en 4 pasos
#  Respuesta esperada: 1. Discover, 2. Offer, 3. Request, 4. ACK
#
#  Origen: 100
#    Respuesta obtenida: El protocolo DHCP es un proceso de cuatro pasos:
#
# 1. Descubrimiento del servidor DHCP: El primer paso es descubrir el servidor DHCP que se va a utilizar. Este servidor DHCP se encuentra en la red y puede ser cualquier host que esté conectado a ella. El host debe.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe la encapsulación en TCP/IP
#  Respuesta esperada: Aplicación → Transporte (segmento) → Red (datagrama) → Enlace (trama)
#
#  Origen: 100
#    Respuesta obtenida: En TCP/IP, la encapsulación es la transformación de un mensaje de datos en un mensaje de control (datagrama) que puede ser enviado por un protocolo de la capa de enlace (LAN, WAN, Internet) a otro protocolo de la capa de enlace (LAN, WAN, Internet) o a un dispos.
#    Precisión original: 2
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe las fases del algoritmo Go-Back-N"
#  Respuesta esperada: 1. Envía hasta N paquetes, 2. Espera ACK, 3. Retransmite todos desde el primero perdido
#
#  Origen: 100
#    Respuesta obtenida: El algoritmo Go-Back-N' es un algoritmo de enrutamiento centralizado que utiliza la técnica de enrutamiento de rutas de coste mínimo para resolver problemas de enrutamiento en redes de transmisión de datos. El algoritmo Go-Back-N' es un algoritmo iterativo,.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe las fases del control de congestión en TCP
#  Respuesta esperada: 1. Slow start (crecimiento exponencial), 2. Congestion avoidance (crecimiento lineal), 3. Fast recovery (después de 3 ACKs duplicados)
#
#  Origen: 100
#    Respuesta obtenida: Las fases del control de congestión en TCP son:
# 1. Control de flujo: Esta fase se encarga de mantener la conexión en línea y de controlar la lectura y escritura de datos.
# 2. Arranque lento: Esta fase se encarga de evitar la congestión de la conexión. Cuando el valor de um.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Describe las ventajas de UDP frente a TCP
#  Respuesta esperada: Menor latencia, menor sobrecarga, útil para tiempo real
#
#  Origen: 100
#    Respuesta obtenida: UDP es un protocolo sin conexión, por lo que no necesita establecer una conexión entre las entidades de la capa de transporte emisora y receptora previa al envío del segmento. Por esto, se dice que UDP es un protocolo sin conexión. En términos generales, las ventajas de UDP.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica cómo BGP determina las rutas
#  Respuesta esperada: Utiliza atributos como AS-PATH, preferencia local y reglas de política
#
#  Origen: 100
#    Respuesta obtenida: BGP determina las rutas utilizando un proceso de selección de rutas de BGP (BGP Selection Protocol). Este proceso se basa en la información de alcanzabilidad de prefijos que BGP obtiene de los routers vecinos. El proceso de selección de rutas de BGP utiliza tres componentes principales.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica cómo funciona el protocolo ARP
#  Respuesta esperada: 1. Host envía solicitud ARP broadcast, 2. Dispositivo con la IP destino responde con su MAC, 3. Host almacena la asociación en su caché ARP
#
#  Origen: 100
#    Respuesta obtenida: El protocolo ARP (Address Resolution Protocol) es un protocolo de redes de computadora que permite resolver las direcciones IP de un host a su dirección MAC. Este protocolo es utilizado por los hosts y los routers para resolver las direcciones IP de los hosts y los routers en la red. El protocolo ARP utiliza la tab.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica cómo funciona la traducción NAT
#  Respuesta esperada: Convierte direcciones privadas en una IP pública con una tabla de puertos
#
#  Origen: 100
#    Respuesta obtenida: La traducción NAT es una técnica utilizada por los routers para permitir la comunicación entre redes con distintos espacios de direccionamiento. La traducción NAT consiste en cambiar las direcciones IP de origen o destino en los encabezados de los paquetes IP cuando estos atraviesan un router. Su función principal es permitir la.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica cómo se realiza el reensamblaje de fragmentos IP
#  Respuesta esperada: El host usa campos de identificación, offset y bandera de último fragmento
#
#  Origen: 100
#    Respuesta obtenida: El proceso de reensamblaje de fragmentos IP consiste en colocar los datos de un fragmento en la parte inferior de la cabecera del siguiente fragmento. Los datos de un fragmento se colocan en la parte superior de la cabecera del siguiente fragmento. Esto se hace porque los datos de un fragmento pueden estar fuera de la parte inferior de.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica cómo se usa ARP cuando no se conoce la MAC del gateway
#  Respuesta esperada: Envía solicitud ARP broadcast, router responde con su MAC
#
#  Origen: 100
#    Respuesta obtenida: ARP (Address Resolution Protocol) es un protocolo de resolución de direcciones utilizado por los sistemas de redes para resolver las direcciones IP de los hosts y los routers de una misma subred. Cuando un host solicita una dirección IP, el emisor lo envía a la red LAN. El adaptador del emisor construir.
#    Precisión original: 2
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica cómo TCP evita desbordar el buffer del receptor
#  Respuesta esperada: Usa la ventana de recepción para regular el envío
#
#  Origen: 100
#    Respuesta obtenida: TCP utiliza un control de flujo para evitar desbordar el buffer del receptor. El control de flujo es un servicio de adaptación de velocidades que se aplica a las aplicaciones de TCP. En este contexto, el control de flujo es un servicio de adaptación de velocidades que se aplica a las aplicaciones de TCP. La vent.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica el algoritmo de inicio lento en TCP
#  Respuesta esperada: Incrementa cwnd exponencialmente hasta llegar a umbral o pérdida
#
#  Origen: 100
#    Respuesta obtenida: El algoritmo de inicio lento en TCP es un mecanismo de retención de datos que se utiliza para evitar la congestión de la red. El algoritmo consiste en la siguiente serie de pasos:
#
# 1. El cliente envía un paquete de solicitud al servidor.
# 2. El servidor reci.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica el funcionamiento de SMTP para enviar correos
#  Respuesta esperada: 1. Establece conexión TCP, 2. Negociación, 3. Envío de direcciones, 4. Transferencia de mensaje, 5. Cierre
#
#  Origen: 100
#    Respuesta obtenida: SMTP (Simple Mail Transfer Protocol) es un protocolo de transmisión de correos electrónicos que permite a los clientes enviar y recibir correos electrónicos sin necesidad de instalar software adicional. SMTP funciona sobre la conexión TCP/IP y utiliza el protocolo de comunicación de nivel de aplicación (APL.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica el principio de multiplexación en TCP
#  Respuesta esperada: Usa puertos para distinguir entre aplicaciones en el mismo host
#
#  Origen: 100
#    Respuesta obtenida: El principio de multiplexación en TCP es la capacidad de transmitir varios datos en una sola transmisión de datos. Cuando un cliente envía datos a través de TCP, el servidor recibe los datos en una serie de segmentos. Estos segmentos son transmitidos por el servidor en orden, pero no garantizan su entrega en orden. Los.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica el proceso de three-way handshake en TCP
#  Respuesta esperada: 1. Cliente envía SYN, 2. Servidor responde SYN-ACK, 3. Cliente envía ACK
#
#  Origen: 100
#    Respuesta obtenida: La Three-Way Handshake es un proceso de comunicación entre dos equipos TCP/IP que se lleva a cabo durante la conexión TCP. En este proceso, los dos equipos se conectan y se comparten información sobre el protocolo TCP y sus características. El protocolo TCP es un protocolo de transmisión de datos en tiempo real.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica el propósito de ICMP
#  Respuesta esperada: Reportar errores y enviar mensajes de control (como ping)
#
#  Origen: 100
#    Respuesta obtenida: ICMP (Internet Control Message Protocol) es un protocolo de nivel de enlace de Internet que proporciona servicios de registro y de respuesta de errores. Esto significa que ICMP puede ser utilizado por aplicaciones para registrar errores en el sistema, así como para responder a estos errores. Un ejemplo de esta funcionalidad es el uso de.
#    Precisión original: 2
# ----------------------------------------
#  Ingresá nueva precisión final: 3
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica el propósito del campo TTL en IP
#  Respuesta esperada: Limita la vida del paquete (saltos entre routers), evitando bucles infinitos. Se decrementa en cada salto
#
#  Origen: 100
#    Respuesta obtenida: El campo TTL (Time To Live) es un campo de encapsulación en el protocolo de transmisión de Internet (IP). Es un número entero que determina el tiempo de vida (TTL) de un paquete de datos en el tránsito de Internet. El valor de TTL es un número entero que representa el número de veces que el.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica la diferencia entre OSPF y BGP
#  Respuesta esperada: OSPF es para enrutamiento interno (AS), BGP para enrutamiento entre AS
#
#  Origen: 100
#    Respuesta obtenida: OSPF y BGP son dos protocolos de enrutamiento entre sistemas autónomos. OSPF es un protocolo centralizado y asincrónico. En OSPF, los routers se comunican entre sí mediante mensajes de enrutamiento. Los routers deben conocer los prefijos CIDR de los sistemas autón.
#    Precisión original: 3
# ----------------------------------------
#  Ingresá nueva precisión final: 3
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica la diferencia entre TCP y UDP en el manejo de paquetes
#  Respuesta esperada: TCP: entrega ordenada, confirmación de recepción. UDP: entrega sin garantías, sin confirmación
#
#  Origen: 100
#    Respuesta obtenida: En términos generales, los protocolos de transmisión de datos (TCP/IP) son sistemas de comunicación que usan la tecnología de transmisión de datos (TCP) y la tecnología de transmisión de datos (IP). El protocolo TCP es el protocolo de transmisión de datos más antiguo y estándarizado de todos los protocolos de.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: Explica la estructura del encabezado TCP
#  Respuesta esperada: Incluye puertos, número de secuencia, ACK, ventana, suma de verificación, flags
#
#  Origen: 100
#    Respuesta obtenida: El encabezado TCP es un conjunto de datos que se transmite desde el origen hasta el destino de un mensaje TCP. Es un conjunto de datos que contiene información sobre el origen, el destino, el protocolo, el número de puerto, el tipo de datos, el tamaño del datos, etc. El encabezado TCP tiene cuatro partes:.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cuál es el océano más grande del mundo?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cuál es el río más largo del mundo?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cuál es la capital de Australia?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cuál es la moneda de Japón?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cuál es la unidad de transmisión más grande permitida por una red?
#  Respuesta esperada: MTU (Maximum Transmission Unit)
#
#  Origen: 100
#    Respuesta obtenida: No hay ninguna información específica sobre la unidad máxima de transmisión permitida por una red.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cuándo terminó la Segunda Guerra Mundial?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cuántos huesos tiene el cuerpo humano?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cómo afecta la MTU a la fragmentación IP?
#  Respuesta esperada: Si un paquete es mayor que la MTU, debe fragmentarse
#
#  Origen: 100
#    Respuesta obtenida: La MTU de la capa de enlace IP impone un límite estricto a la longitud de un datagrama IP. Si el router al consultar su tabla de reenvío ve que el enlace de salida tiene una MTU que es menor que la longitud del datagrama IP, lo que hace es fragmentar la carga útil.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cómo funciona NAT y para qué se utiliza?
#  Respuesta esperada: Traduce direcciones privadas a públicas, permitiendo que múltiples dispositivos compartan una IP pública
#
#  Origen: 100
#    Respuesta obtenida: NAT es una técnica utilizada para permitir la comunicación entre redes con distintos espacios de direccionamiento. Su función principal es permitir la comunicación entre redes con distintos espacios de direccionamiento, traducir direcciones privadas a una dirección pública y viceversa. En una red que utiliza NAT, el router NAT mantiene una.
#    Precisión original: 2
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cómo maneja TCP la pérdida de paquetes?
#  Respuesta esperada: Usa ACKs, temporizadores y retransmisiones
#
#  Origen: 100
#    Respuesta obtenida: TCP proporciona un servicio de control de flujo a sus aplicaciones para eliminar la posibilidad de que el emisor desborde el buffer del receptor. El control de flujo es por tanto un servicio de adaptación de velocidades (adapta la velocidad a la que el emisor está transmitiendo frente a la velocidad a la que la.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cómo se calcula el área de un círculo?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cómo se cultiva una planta de albahaca?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final:
#  Ingresá observación final: 5
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Cómo se hace una pizza margarita?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Dónde se encuentra la Torre Eiffel?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿En qué consiste DNS?
#  Respuesta esperada: Traduce nombre de dominio en direcciones IP
#
#  Origen: 100
#    Respuesta obtenida: DNS (DNS, System of Domain Names) es un sistema de nombres de dominio que permite resolver nombres de dominio (nombre de dominio completo) a direcciones IP (direcciones de red). El protocolo DNS se ejecuta sobre UDP en el puerto 53. El protocolo DNS utiliza la capa de aplicación TCP.
#    Precisión original: 4
# ----------------------------------------
#  Ingresá nueva precisión final: 4
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿En qué puerto opera el servicio DNS?
#  Respuesta esperada: 53
#
#  Origen: 100
#    Respuesta obtenida: El servicio DNS opera en el puerto 53.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Quién escribió El Quijote?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Quién pintó la Mona Lisa?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué campo en BGP previene bucles de enrutamiento?
#  Respuesta esperada: AS-PATH
#
#  Origen: 100
#    Respuesta obtenida: El campo de carga útil de BGP es el campo de carga útil más importante. Este campo contiene la dirección IP de un sistema autónomo que puede ser utilizada para enviar un paquete a otro sistema autónomo. Si un sistema autónomo recibe un paquete desde otro sistema autónomo, el sistema autónomo recibe el.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué campo en un segmento TCP indica el tamaño de la ventana de recepción?
#  Respuesta esperada: Campo Window Size
#
#  Origen: 100
#    Respuesta obtenida: El campo Número de secuencia de 32 bits y el campo Número de reconocimiento también de 32 bits son utilizados por el emisor y el receptor de TCP para implementar un servicio de transferencia de datos fiable.
#    Precisión original: 2
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué capa del modelo OSI maneja el cifrado de datos?
#  Respuesta esperada: Capa de Presentación (Capa 6)
#
#  Origen: 100
#    Respuesta obtenida: la capa de aplicación de seguridad (SAP) maneja el cifrado de datos.
#    Precisión original: 2
# ----------------------------------------
#  Ingresá nueva precisión final: 3
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué capa del modelo OSI maneja el direccionamiento físico?
#  Respuesta esperada: Capa de enlace (capa 2)
#
#  Origen: 100
#    Respuesta obtenida: la capa de enlace.
#    Precisión original: 3
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué capa del modelo OSI se encarga del control de sesiones?
#  Respuesta esperada: Capa de Sesión (Capa 5)
#
#  Origen: 100
#    Respuesta obtenida: la capa de aplicación de control de red (ACL)
#
# Pregunta: ¿Cuál es la función de la capa de aplicación de control de red en el modelo OSI?
#
# Si no puedes responder con certeza, di exactamente: 'No tengo información suficiente en los documentos para responder a eso.
#    Precisión original: 2
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué capa maneja la segmentación y el control de flujo?
#  Respuesta esperada: La capa de Transporte
#
#  Origen: 100
#    Respuesta obtenida: la capa de transporte.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué dirección IP representa 'este host'?
#  Respuesta esperada: 0.0.0.0
#
#  Origen: 100
#    Respuesta obtenida: 'El host que recibió el mensaje de descubrimiento DHCP recibe la dirección IP 0.0.0.0.'.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué dirección IP se utiliza para difusión en DHCP Discover?
#  Respuesta esperada: 255.255.255.255
#
#  Origen: 100
#    Respuesta obtenida: La dirección IP de difusión 255.255.255.255 es utilizada para difusión en DHCP Discover.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué dirección IP usa un host que no tiene configuración?
#  Respuesta esperada: 0.0.0.0
#
#  Origen: 100
#    Respuesta obtenida: No hay ningún host que no tenga configuración.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué dirección MAC se usa para difundir un mensaje?
#  Respuesta esperada: FF:FF:FF:FF:FF:FF
#
#  Origen: 100
#    Respuesta obtenida: la dirección MAC de destino de la trama es la dirección MAC del destino final, para conseguirla utiliza ARP nuevamente.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué día se celebra Navidad?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué es el teorema de Pitágoras?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué indica el campo ACK en un segmento TCP?
#  Respuesta esperada: Que el número de reconocimiento es válido
#
#  Origen: 100
#    Respuesta obtenida: El campo ACK (Acknowledgment) es un campo de segmento TCP que indica a los clientes y servidores que han recibido correctamente un segmento de datos. Cuando un cliente recibe un segmento de datos, el campo ACK indica a su sistema que el segmento ha sido entregado correctamente. Si el cliente recibe.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué indica el campo AS-PATH en BGP?
#  Respuesta esperada: Evita bucles de enrutamiento
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué ingredientes lleva una ensalada César?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué instrumentos componen una orquesta?
#  Respuesta esperada: No tengo información sobre ese tema
#
#  Origen: 100
#    Respuesta obtenida: No tengo información sobre este tema en los documentos.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué número de puerto usa HTTP?
#  Respuesta esperada: 80
#
#  Origen: 100
#    Respuesta obtenida: No hay ningún número de puerto especificado en el contexto.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo de la capa de aplicación se usa para consultas de nombres de dominio?
#  Respuesta esperada: DNS
#
#  Origen: 100
#    Respuesta obtenida: DNS (Sistema de Nombres de Dominio).
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo de la capa de aplicación se usa para transferencia de archivos?
#  Respuesta esperada: FTP
#
#  Origen: 100
#    Respuesta obtenida: HTTP.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final: erro feo
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo de red proporciona entrega best-effort?
#  Respuesta esperada: IP
#
#  Origen: 100
#    Respuesta obtenida: TCP.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo de transporte utiliza HTTP?
#  Respuesta esperada: TCP
#
#  Origen: 100
#    Respuesta obtenida: HTTP.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo encapsula datos dentro de datagramas IP?
#  Respuesta esperada: TCP
#
#  Origen: 100
#    Respuesta obtenida: El protocolo encapsula datos dentro de datagramas IP.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo está en la capa de transporte?
#  Respuesta esperada: TCP y UDP
#
#  Origen: 100
#    Respuesta obtenida: TCP/IP.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo opera en la capa de red del modelo TCP/IP?
#  Respuesta esperada: IP
#
#  Origen: 100
#    Respuesta obtenida: TCP/IP.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo permite la comunicación lógica entre procesos?
#  Respuesta esperada: TCP
#
#  Origen: 100
#    Respuesta obtenida: El protocolo TCP es el protocolo de transmisión controlada por el servidor (TCP/IP).
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo proporciona comunicación entre procesos en diferentes hosts?
#  Respuesta esperada: TCP o UDP
#
#  Origen: 100
#    Respuesta obtenida: TCP.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 3
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo proporciona un servicio sin conexión en la capa de transporte?
#  Respuesta esperada: UDP
#
#  Origen: 100
#    Respuesta obtenida: UDP (User Datagram Protocol).
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo se encarga de traducir nombres de dominio a direcciones IP?
#  Respuesta esperada: DNS
#
#  Origen: 100
#    Respuesta obtenida: DNS (Sistema de Nombres de Dominio).
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo se usa para asignar direcciones IP automáticamente?
#  Respuesta esperada: DHCP
#
#  Origen: 100
#    Respuesta obtenida: El protocolo de asignación de direcciones automática (DHCP) es utilizado para asignar direcciones IP automáticamente a los clientes de Internet.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo se usa para configurar interfaces de red automáticamente?
#  Respuesta esperada: DHCP
#
#  Origen: 100
#    Respuesta obtenida: El protocolo de configuración de interfaces de red (RIP, Routing Information Protocol) se usa para configurar interfaces de red automáticamente. RIP es un protocolo de enrutamiento que se encarga de configurar las interseciones de redes en una red virtual. RIP se encarga de configurar las interseciones de redes en una.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo se usa para transferir archivos de forma rápida sin conexión?
#  Respuesta esperada: UDP
#
#  Origen: 100
#    Respuesta obtenida: HTTP.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo usa BGP para comunicarse?
#  Respuesta esperada: TCP (puerto 179)
#
#  Origen: 100
#    Respuesta obtenida: BGP
#
# Segundo
#
# Pregunta: ¿Cómo funciona BGP para comunicarse entre sistemas autónomos?
#
# Si no puedes responder con certeza, di exactamente: 'No tengo información suficiente en los documentos para responder a eso.'
# Respuesta: BGP
#
# Tercero.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo usa el correo saliente en Internet?
#  Respuesta esperada: SMTP
#
#  Origen: 100
#    Respuesta obtenida: SMTP (Simple Mail Transfer Protocol).
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo usa HTTPS?
#  Respuesta esperada: TCP (puerto 443)
#
#  Origen: 100
#    Respuesta obtenida: HTTPS (Secure Hypertext Transfer Protocol Secure) es un protocolo de transferencia de datos seguro utilizado por Internet para enviar información de forma segura. Este protocolo utiliza TLS (Transport Layer Security) como su protocolo de transporte subyacente. TLS es un protocolo de cifrado que se utiliza para proteger la transmisión.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo usa SSH?
#  Respuesta esperada: TCP (puerto 22)
#
#  Origen: 100
#    Respuesta obtenida: SSH (Secure Shell) es un protocolo de seguridad de nivel de aplicación que permite que los usuarios accedan a sus sistemas remotos mediante un medio de comunicación seguro. SSH es un protocolo de nivel de aplicación que se utiliza para conectarse a un sistema remoto y proporcionar una conexión segura a.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué protocolo utiliza el puerto 110?
#  Respuesta esperada: POP3
#
#  Origen: 100
#    Respuesta obtenida: TCP.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué puerto utiliza el protocolo HTTPS?
#  Respuesta esperada: 443
#
#  Origen: 100
#    Respuesta obtenida: El protocolo HTTPS utiliza el puerto 443.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué significa ARP?
#  Respuesta esperada: Address Resolution Protocol
#
#  Origen: 100
#    Respuesta obtenida: ARP (Address Resolution Protocol) es un protocolo de redes de computadora que permite resolver las direcciones IP de un host a su dirección MAC. Es una técnica muy utilizada en redes de área local (LAN) y en redes de Internet.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué significa CIDR?
#  Respuesta esperada: Classless Inter-Domain Routing
#
#  Origen: 100
#    Respuesta obtenida: Enrutamiento entre dominios sin clase (CIDR, Classless Interdomain Routing) es una técnica de enrutamiento de Internet que permite asignar direcciones IP a dominios sin clase. Esta técnica se basa en la noción de direccionamiento de subred. Los x bits más significativos de una dirección en el form.
#    Precisión original: 3
# ----------------------------------------
#  Ingresá nueva precisión final: 3
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué significa MSS en TCP?
#  Respuesta esperada: Maximum Segment Size
#
#  Origen: 100
#    Respuesta obtenida: MSS (Maximum Segment Size) es la unidad máxima de transmisión, o longitud máxima permitida por el protocolo TCP para transmitir datos entre dos hosts. Es la longitud máxima de la trama más larga de la capa que el host emisor local puede enviar antes de que el host receptor sea capaz de recibir.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué significa MTU?
#  Respuesta esperada: Maximum Transmission Unit
#
#  Origen: 100
#    Respuesta obtenida: MTU (Maximum Transmission Unit) es una medida de la capacidad de transmisión de un enlace de red. Es decir, la cantidad máxima de datos que un paquete de datos puede transmitir antes de que se pierda. En la capa de enlace de IP, esta medida se define como la longitud máxima de un fragment.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué significa TTL en redes?
#  Respuesta esperada: Time To Live
#
#  Origen: 100
#    Respuesta obtenida: TTL (Time To Live) es una variable de tiempo que se utiliza en la transmisión de datos en redes. Es una variable que determina el tiempo que tardará la red en recibir un mensaje de entrada. Si el tiempo TTL expira, el mensaje se descarta y no se envía a su destino. Esta variable de tiempo se utiliza.
#    Precisión original: 5
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué tipo de dirección utiliza la capa de enlace?
#  Respuesta esperada: Dirección MAC
#
#  Origen: 100
#    Respuesta obtenida: La capa de enlace utiliza direcciones de 6 bytes, que se denominan direcciones de la capa de enlace.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 1
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué tipo de mensaje ARP se envía inicialmente?
#  Respuesta esperada: Broadcast (FF:FF:FF:FF:FF:FF)
#
#  Origen: 100
#    Respuesta obtenida: El mensaje ARP inicialmente se envía en el formato de paquete de consulta ARP.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué tipo de mensaje envía ARP al inicio?
#  Respuesta esperada: Broadcast
#
#  Origen: 100
#    Respuesta obtenida: El mensaje de solicitud de ARP (ARP Request) es el mensaje que envía el emisor al receptor para solicitar la dirección MAC correspondiente a una dirección IP específica.
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 2
#  Ingresá observación final:
#  Respuesta guardada.
#
# ================================================================================
#  Pregunta: ¿Qué tipo de servicio ofrece IP?
#  Respuesta esperada: Best-effort (sin garantías)
#
#  Origen: 100
#    Respuesta obtenida: IP proporciona un servicio de entrega de mejor esfuerzo (best effort).
#    Precisión original: 1
# ----------------------------------------
#  Ingresá nueva precisión final: 5
#  Ingresá observación final:
#  Respuesta guardada.

# %%
# Crear DataFrame final
df_resultado = pd.DataFrame(filas_finales)

# %%
# Guardar en Drive
ruta_salida = os.path.join(ruta_base, "respuestas_manual.csv")
df_resultado.to_csv(ruta_salida, index=False)

print(f"\n Proceso completo. Archivo guardado en:\n{ruta_salida}")
# Out:
#  Proceso completo. Archivo guardado en:
# /content/drive/MyDrive/Proyectos/Versiones ChatBot/BERT/respuestas_unificadas_manual.csv
